# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv(r"D:\Data Science\Projects\Store Sales - Time Series Forecasting\train.csv")

data.info()

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
data["year"] = data["date"].dt.year
data["month"] = data["date"].dt.month
data["day"] = data["date"].dt.day
data["dayofweek"] = data["date"].dt.dayofweek

# %%
features = ["store_nbr", "family", "onpromotion", "year", "month", "day", "dayofweek"]

data["family"] = data["family"].astype("category").cat.codes

x = data[features]
y = data["sales"]

# %%
print("Training started")

model.fit(X_train, y_train)

print("Training finished")

# %%
train = data[data["date"] < "2017-01-01"]
valid = data[data["date"] >= "2017-01-01"]

x_train = train[features]
y_train = train["sales"]

x_valid = valid[features]
y_valid = valid["sales"]

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)

# %%
preds = model.predict(x_valid)

# %%
rmse = np.sqrt(mean_squared_error(y_valid, preds))
print("RMSE:", rmse)
